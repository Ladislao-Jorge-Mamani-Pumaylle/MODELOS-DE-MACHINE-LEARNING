# %% [markdown]
# <a href="https://colab.research.google.com/github/Ladislao-Mamani-Pumaylle/MODELOS-DE-MACHINE-LEARNING/blob/main/An%C3%A1lisis_de_sentimientos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
f1="I love this place"
f2="I hate this restaurant"
f3="I have nothing to say"

# %%
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# True

# %%
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
sia=SentimentIntensityAnalyzer()

# %%
resultSentimiento=sia.polarity_scores(f1)
print(resultSentimiento)
# Out:
# {'neg': 0.0, 'neu': 0.323, 'pos': 0.677, 'compound': 0.6369}

# %% [markdown]
# Creamos una función que me devuelva la etiqueta en base a los rangos que yo le asigne
